# %%
# !gdown --id 1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu
# Out:
# C:\Users\Administrator\anaconda3\envs\aio2024_env\Lib\site-packages\gdown\__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu
# To: d:\AIO-module-5\MLP\Auto_MPG_data.csv
#
#   0%|          | 0.00/15.4k [00:00<?, ?B/s]
# 100%|██████████| 15.4k/15.4k [00:00<00:00, 7.73MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

# %%
device = torch.device('cuda' if torch.cuda.is_available()else 'cpu')

# %%
dataset_path = 'Auto_MPG_data.csv'
dataset = pd.read_csv(dataset_path)

# %%
X = dataset.drop(columns ='MPG').values
y = dataset['MPG'].values

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
X, y,
test_size = val_size,
random_state = random_state,
shuffle = is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
X_train, y_train,
test_size = test_size,
random_state = random_state,
shuffle = is_shuffle
)

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype = torch.float32)
X_val = torch.tensor(X_val, dtype = torch.float32)
X_test = torch.tensor(X_test, dtype = torch.float32)
y_train = torch.tensor(y_train, dtype = torch.float32)
y_val = torch.tensor(y_val, dtype = torch.float32)
y_test = torch.tensor(y_test, dtype = torch.float32)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[ idx ], self.y[ idx ]

# %%
batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
train_loader = DataLoader(train_dataset,batch_size = batch_size,shuffle = True)
val_loader = DataLoader(val_dataset,batch_size = batch_size,shuffle = False)

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        out = self.output(x)
        return out.squeeze(1)

# %%
input_dims = X_train.shape [1]
output_dims = 1
hidden_dims = 64

model = MLP(input_dims= input_dims,hidden_dims= hidden_dims,output_dims= output_dims).to(device)

# %%
lr = 1e-2
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
def r_squared(y_true , y_pred):
    y_true = torch.Tensor(y_true).to(device)
    y_pred = torch.Tensor(y_pred).to(device)
    mean_true = torch.mean(y_true)
    ss_tot = torch.sum((y_true - mean_true)** 2)
    ss_res = torch.sum((y_true - y_pred)** 2)
    r2 = 1 -(ss_res / ss_tot)
    return r2

# %%
epochs = 100
train_losses = []
val_losses = []
train_r2 = []
val_r2 = []
for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    val_target = []
    train_predict = []
    val_predict = []
    model.train()
    for X_samples , y_samples in train_loader :
        X_samples = X_samples .to(device)
        y_samples = y_samples .to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        train_predict += outputs.tolist()
        train_target += y_samples.tolist()
        loss = criterion(outputs , y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r_squared(train_target , train_predict))
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_samples , y_samples in val_loader :
            X_samples = X_samples .to(device)
            y_samples = y_samples .to(device)
            outputs = model(X_samples)
            val_predict += outputs.tolist()
            val_target += y_samples.tolist()
            loss = criterion(outputs , y_samples)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r_squared(val_target , val_predict))
    print(f'\nEPOCH { epoch + 1}:\ tTraining loss : { train_loss:.3f}\
    tValidation loss : {val_loss:.3f}')
# Out:
# EPOCH 1:\ tTraining loss : 282.770    tValidation loss : 88.671
#
# EPOCH 2:\ tTraining loss : 137.640    tValidation loss : 72.293
#
# EPOCH 3:\ tTraining loss : 71.207    tValidation loss : 19.668
#
# EPOCH 4:\ tTraining loss : 24.286    tValidation loss : 166.905
#
# EPOCH 5:\ tTraining loss : 89.477    tValidation loss : 19.816
#
# EPOCH 6:\ tTraining loss : 17.982    tValidation loss : 17.116
#
# EPOCH 7:\ tTraining loss : 20.667    tValidation loss : 8.669
#
# EPOCH 8:\ tTraining loss : 38.545    tValidation loss : 36.080
#
# EPOCH 9:\ tTraining loss : 20.425    tValidation loss : 30.156
#
# EPOCH 10:\ tTraining loss : 20.308    tValidation loss : 49.483
#
# EPOCH 11:\ tTraining loss : 33.849    tValidation loss : 21.479
#
# EPOCH 12:\ tTraining loss : 10.136    tValidation loss : 5.739
#
# EPOCH 13:\ tTraining loss : 15.319    tValidation loss : 15.422
#
# EPOCH 14:\ tTraining loss : 12.338    tValidation loss : 13.156
#
# EPOCH 15:\ tTraining loss : 14.816    tValidation loss : 8.520
#
# EPOCH 16:\ tTraining loss : 11.111    tValidation loss : 20.013
#
# EPOCH 17:\ tTraining loss : 12.707    tValidation loss : 14.488
#
# EPOCH 18:\ tTraining loss : 15.631    tValidation loss : 13.129
#
# EPOCH 19:\ tTraining loss : 15.932    tValidation loss : 5.366
#
# EPOCH 20:\ tTraining loss : 7.311    tValidation loss : 5.066
#
# EPOCH 21:\ tTraining loss : 8.646    tValidation loss : 4.605
#
# EPOCH 22:\ tTraining loss : 6.176    tValidation loss : 5.447
#
# EPOCH 23:\ tTraining loss : 10.284    tValidation loss : 51.102
#
# EPOCH 24:\ tTraining loss : 11.050    tValidation loss : 14.580
#
# EPOCH 25:\ tTraining loss : 9.005    tValidation loss : 8.600
#
# EPOCH 26:\ tTraining loss : 10.426    tValidation loss : 6.209
#
# EPOCH 27:\ tTraining loss : 6.249    tValidation loss : 7.060
#
# EPOCH 28:\ tTraining loss : 10.701    tValidation loss : 4.864
#
# EPOCH 29:\ tTraining loss : 6.526    tValidation loss : 11.746
#
# EPOCH 30:\ tTraining loss : 18.247    tValidation loss : 4.692
#
# EPOCH 31:\ tTraining loss : 8.116    tValidation loss : 6.227
#
# EPOCH 32:\ tTraining loss : 7.006    tValidation loss : 6.256
#
# EPOCH 33:\ tTraining loss : 7.299    tValidation loss : 4.595
#
# EPOCH 34:\ tTraining loss : 6.806    tValidation loss : 6.235
#
# EPOCH 35:\ tTraining loss : 7.703    tValidation loss : 6.427
#
# EPOCH 36:\ tTraining loss : 6.019    tValidation loss : 6.133
#
# EPOCH 37:\ tTraining loss : 6.233    tValidation loss : 6.115
#
# EPOCH 38:\ tTraining loss : 7.423    tValidation loss : 10.264
#
# EPOCH 39:\ tTraining loss : 7.643    tValidation loss : 13.870
#
# EPOCH 40:\ tTraining loss : 7.529    tValidation loss : 5.453
#
# EPOCH 41:\ tTraining loss : 5.949    tValidation loss : 22.200
#
# EPOCH 42:\ tTraining loss : 8.370    tValidation loss : 5.686
#
# EPOCH 43:\ tTraining loss : 7.331    tValidation loss : 28.401
#
# EPOCH 44:\ tTraining loss : 9.872    tValidation loss : 11.740
#
# EPOCH 45:\ tTraining loss : 6.734    tValidation loss : 4.843
#
# EPOCH 46:\ tTraining loss : 8.451    tValidation loss : 7.271
#
# EPOCH 47:\ tTraining loss : 6.469    tValidation loss : 6.037
#
# EPOCH 48:\ tTraining loss : 5.397    tValidation loss : 6.278
#
# EPOCH 49:\ tTraining loss : 6.683    tValidation loss : 10.092
#
# EPOCH 50:\ tTraining loss : 6.824    tValidation loss : 11.924
#
# EPOCH 51:\ tTraining loss : 8.220    tValidation loss : 8.378
#
# EPOCH 52:\ tTraining loss : 11.057    tValidation loss : 5.205
#
# EPOCH 53:\ tTraining loss : 7.374    tValidation loss : 4.892
#
# EPOCH 54:\ tTraining loss : 6.581    tValidation loss : 5.573
#
# EPOCH 55:\ tTraining loss : 5.611    tValidation loss : 5.023
#
# EPOCH 56:\ tTraining loss : 5.606    tValidation loss : 6.312
#
# EPOCH 57:\ tTraining loss : 7.789    tValidation loss : 7.280
#
# EPOCH 58:\ tTraining loss : 6.893    tValidation loss : 18.149
#
# EPOCH 59:\ tTraining loss : 7.420    tValidation loss : 8.015
#
# EPOCH 60:\ tTraining loss : 5.804    tValidation loss : 4.881
#
# EPOCH 61:\ tTraining loss : 5.704    tValidation loss : 8.084
#
# EPOCH 62:\ tTraining loss : 9.990    tValidation loss : 4.557
#
# EPOCH 63:\ tTraining loss : 6.582    tValidation loss : 13.206
#
# EPOCH 64:\ tTraining loss : 6.312    tValidation loss : 6.351
#
# EPOCH 65:\ tTraining loss : 7.986    tValidation loss : 5.406
#
# EPOCH 66:\ tTraining loss : 5.392    tValidation loss : 5.122
#
# EPOCH 67:\ tTraining loss : 5.963    tValidation loss : 6.023
#
# EPOCH 68:\ tTraining loss : 10.433    tValidation loss : 7.081
#
# EPOCH 69:\ tTraining loss : 7.142    tValidation loss : 8.915
#
# EPOCH 70:\ tTraining loss : 6.270    tValidation loss : 5.275
#
# EPOCH 71:\ tTraining loss : 5.220    tValidation loss : 4.737
#
# EPOCH 72:\ tTraining loss : 5.975    tValidation loss : 9.286
#
# EPOCH 73:\ tTraining loss : 6.782    tValidation loss : 10.709
#
# EPOCH 74:\ tTraining loss : 6.508    tValidation loss : 5.220
#
# EPOCH 75:\ tTraining loss : 5.533    tValidation loss : 17.225
#
# EPOCH 76:\ tTraining loss : 7.614    tValidation loss : 19.814
#
# EPOCH 77:\ tTraining loss : 11.201    tValidation loss : 7.163
#
# EPOCH 78:\ tTraining loss : 6.812    tValidation loss : 5.336
#
# EPOCH 79:\ tTraining loss : 6.054    tValidation loss : 10.923
#
# EPOCH 80:\ tTraining loss : 8.110    tValidation loss : 5.554
#
# EPOCH 81:\ tTraining loss : 10.670    tValidation loss : 6.365
#
# EPOCH 82:\ tTraining loss : 5.650    tValidation loss : 5.421
#
# EPOCH 83:\ tTraining loss : 5.668    tValidation loss : 8.135
#
# EPOCH 84:\ tTraining loss : 5.345    tValidation loss : 5.082
#
# EPOCH 85:\ tTraining loss : 5.065    tValidation loss : 6.833
#
# EPOCH 86:\ tTraining loss : 4.891    tValidation loss : 6.219
#
# EPOCH 87:\ tTraining loss : 5.249    tValidation loss : 7.431
#
# EPOCH 88:\ tTraining loss : 5.247    tValidation loss : 5.144
#
# EPOCH 89:\ tTraining loss : 4.860    tValidation loss : 5.588
#
# EPOCH 90:\ tTraining loss : 6.919    tValidation loss : 6.482
#
# EPOCH 91:\ tTraining loss : 5.541    tValidation loss : 7.963
#
# EPOCH 92:\ tTraining loss : 6.963    tValidation loss : 5.534
#
# EPOCH 93:\ tTraining loss : 6.316    tValidation loss : 5.047
#
# EPOCH 94:\ tTraining loss : 9.285    tValidation loss : 7.355
#
# EPOCH 95:\ tTraining loss : 6.474    tValidation loss : 6.146
#
# EPOCH 96:\ tTraining loss : 8.351    tValidation loss : 19.258
#
# EPOCH 97:\ tTraining loss : 7.047    tValidation loss : 10.022
#
# EPOCH 98:\ tTraining loss : 7.011    tValidation loss : 7.519
#
# EPOCH 99:\ tTraining loss : 6.176    tValidation loss : 5.104
#
# EPOCH 100:\ tTraining loss : 6.029    tValidation loss : 4.869

# %%
model.eval ()
with torch.no_grad () :
    y_hat = model(X_test.to( device ))
    test_set_r2 = r_squared (y_hat , y_test)
    print ('Evaluation on test set :')
    print (f'R2: {test_set_r2}')
# Out:
# Evaluation on test set :
# R2: 0.8407537937164307
